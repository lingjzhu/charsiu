# %% [markdown]
# <a href="https://colab.research.google.com/github/lingjzhu/charsiu/blob/development/charsiu_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import torch
from datasets import load_dataset
import matplotlib.pyplot as plt

sys.path.insert(0,'src')
from models import Wav2Vec2ForAttentionAlignment
from utils import get_phones, get_phone_ids

# %%
# load model
model = Wav2Vec2ForAttentionAlignment.from_pretrained('charsiu/en_w2v2_fs_10ms')

# %%
# download timit
timit = load_dataset('timit_asr')

# %%
text = 'this is a phone'
get_phone_ids(get_phones(text))
